# %% [markdown]
# # 🏥 Medical QA Fine-tuning with QLoRA
#
# This notebook fine-tunes TinyLlama-1.1B on the MedMCQA dataset using QLoRA.
#
# **Instructions:**
# 1. Go to Runtime > Change runtime type > Select **T4 GPU**
# 2. Run all cells in order
# 3. Download the adapter weights at the end

# %%
# !pip install -q transformers>=4.36.0 peft>=0.7.0 bitsandbytes>=0.41.0 accelerate>=0.25.0 datasets trl scipy

# %%
import torch
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
from datasets import load_dataset
print('Loading MedMCQA...')
dataset = load_dataset('openlifescienceai/medmcqa', split='train')
dataset = dataset.shuffle(seed=42).select(range(5000))
print(f'Using {len(dataset)} samples')
